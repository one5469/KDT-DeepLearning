# %% [markdown]
# ### Dataset & DataLoader 살펴보기
# - Pytorch에서 배치크기만큼 데이터를 조절하기 위한 메카니즘
# - Dataset : 사용 데이터를 기반으로 사용자정의 클래스 작성
# - DataLoader : 지정된 Dataset에서 지정된 batch size만큼 피쳐와 타겟을 추출하여 전달

# %% [markdown]
# [1] 모듈 로딩 및 데이터 준비

# %%
### ===> 모듈 로딩
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pandas as pd

# %%
### ===> 데이터 준비
x_data = torch.IntTensor([[10,20,30], [20,30,40], [30,40,50], [40,50,60], [50,60,70]])
y_data = torch.FloatTensor([[20], [30], [40], [50], [60]])

print(f'x_data => {x_data.shape} {x_data.ndim}D')
print(f'y_data => {y_data.shape} {y_data.ndim}D')
# Out:
# x_data => torch.Size([5, 3]) 2D
# y_data => torch.Size([5, 1]) 2D

# %% [markdown]
# [2] 데이터셋 생성

# %% [markdown]
# - [2-1] TensorDataset 활용 : Dataset의 sub_class

# %%
# TensorDataset 클래스 로딩
from torch.utils.data import TensorDataset

# %%
dataset = TensorDataset(x_data, y_data)
dataset

# %%
# __getitems__() 호출
dataset[0]
# Out:
# (tensor([10, 20, 30], dtype=torch.int32), tensor([20.]))

# %%
len(dataset)
# Out:
# 5

# %% [markdown]
# - [2-2] 사용자정의 데이터셋 생성

# %%
### 데이터 준비
filename = '../data/iris.csv'

# %%
irisDF = pd.read_csv(filename)
irisDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
### 사용자정의 DataSet 클래스
# - 데이터의 Tensor 변환
class DLDataset(Dataset):
    # 초기화 함수
    def __init__(self, x_data, y_data):
        super().__init__()
        
        # x, y 데이터 ==> ndarray
        x_data = x_data.values if isinstance(x_data, pd.DataFrame) else x_data
        y_data = y_data.values if isinstance(y_data, pd.DataFrame) else y_data
        
        # ndarray ==> tensor
        self.feature = torch.tensor(x_data)
        self.target = torch.tensor(y_data)
        
    # 데이터셋의 갯수 체크 함수
    def __len__(self):
        return len(self.target)
    
    # 특정 인덱스 데이터+라벨 반환 콜백 함수(callback function)
    def __getitem__(self, index):
        return self.feature[index], self.target[index]

# %%
if irisDF.__class__.__name__ == 'DataFrame':
    print('DF')
# Out:
# DF

# %%
isinstance(irisDF, pd.DataFrame), isinstance({'A':22}, list)
# Out:
# (True, False)

# %%
irisDF[irisDF.columns[-1]].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
# 피쳐와 라벨로 분리
featureDF = irisDF[irisDF.columns[:-1]]
targetDF = irisDF[[irisDF.columns[-1]]].replace({'setosa':0, 'versicolor':1, 'virginica':2})

print(f'featureDF => {featureDF.shape}, {featureDF.ndim}D')
print(f'targetDF => {targetDF.shape}, {targetDF.ndim}D')
# Out:
# featureDF => (150, 4), 2D
# targetDF => (150, 1), 2D

# %%
# 데이터셋 생성
my_dataset = DLDataset(featureDF.values, targetDF.values)

# %%
my_dataset = DLDataset(featureDF, targetDF.values)

# %%
my_dataset

# %% [markdown]
# - [2-3] 학습용, 검증용, 테스트용 Dataset

# %%
### ===> 파이토치
from torch.utils.data import random_split

# 학습용, 검증용, 테스트 데이터 비율
seed = torch.Generator().manual_seed(42)

trainDS, validDS, testDS = random_split(my_dataset, [0.7, 0.1, 0.2], generator=seed)

print(f'trainDS => {len(trainDS)}개, validDS => {len(validDS)}개, testDS => {len(testDS)}개')

print(f'Subset 속성=>\nindices : {trainDS.indices} \ndataset : {trainDS.dataset}')
print(f'Subset 속성=>\nindices : {validDS.indices} \ndataset : {validDS.dataset}')
# Out:
# trainDS => 105개, validDS => 15개, testDS => 30개
# Subset 속성=>
# indices : [42, 95, 30, 64, 52, 35, 130, 40, 82, 17, 108, 94, 68, 97, 117, 127, 41, 44, 57, 140, 149, 32, 23, 102, 16, 113, 71, 18, 67, 66, 0, 25, 101, 112, 91, 3, 59, 116, 86, 84, 106, 142, 43, 39, 26, 98, 93, 20, 87, 19, 120, 114, 7, 63, 76, 89, 36, 45, 37, 56, 58, 122, 51, 145, 24, 21, 105, 62, 15, 11, 48, 133, 88, 50, 6, 134, 111, 8, 49, 75, 69, 124, 4, 147, 80, 100, 99, 141, 47, 107, 13, 109, 129, 28, 38, 53, 121, 5, 55, 31, 73, 74, 54, 29, 12]
# dataset : <__main__.DLDataset object at 0x000001560495C4F0>
# Subset 속성=>
# indices : [22, 104, 81, 1, 103, 125, 85, 2, 96, 128, 27, 118, 77, 110, 146]
# dataset : <__main__.DLDataset object at 0x000001560495C4F0>

# %% [markdown]
# [3] DataLoader 생성 : 학습용, 검증용, 테스트용

# %%
# DataLoader 생성
# drop_last 매개변수 : 배치사이즈로 데이터셋 분리 후 남는 데이터 처리 방법 설정 [기본: False]
batch = 5
trainDL = DataLoader(trainDS, batch_size=batch)
validDL = DataLoader(validDS, batch_size=batch)
testDL = DataLoader(testDS, batch_size=batch)

len(trainDL), len(validDL), len(testDL)
# Out:
# (21, 3, 6)

# %%
# Epoch당 반복 단위
print('batch_size :', batch)
print(f'trainDS => {len(trainDS)}개, validDS => {len(validDS)}개, testDS => {len(testDS)}개')
print(f'trainDL => {len(trainDL)}개, validDS => {len(validDL)}개, testDS => {len(testDL)}개')
# Out:
# batch_size : 5
# trainDS => 105개, validDS => 15개, testDS => 30개
# trainDL => 21개, validDS => 3개, testDS => 6개

# %%
# DataLoader 속성
for _, (feature, target) in enumerate(trainDL):
    print(f'[{_}] feature {feature.shape}')
# Out:
# [0] feature torch.Size([5, 4])
# [1] feature torch.Size([5, 4])
# [2] feature torch.Size([5, 4])
# [3] feature torch.Size([5, 4])
# [4] feature torch.Size([5, 4])
# [5] feature torch.Size([5, 4])
# [6] feature torch.Size([5, 4])
# [7] feature torch.Size([5, 4])
# [8] feature torch.Size([5, 4])
# [9] feature torch.Size([5, 4])
# [10] feature torch.Size([5, 4])
# [11] feature torch.Size([5, 4])
# [12] feature torch.Size([5, 4])
# [13] feature torch.Size([5, 4])
# [14] feature torch.Size([5, 4])
# [15] feature torch.Size([5, 4])
# [16] feature torch.Size([5, 4])
# [17] feature torch.Size([5, 4])
# [18] feature torch.Size([5, 4])
# [19] feature torch.Size([5, 4])
# [20] feature torch.Size([5, 4])

# %% [markdown]
# [4] Model 클래스 정의 : 입/출력 피쳐수, 층 수, 은닉층의 노드수
# - 구조 설계
#     * 입력층 : 입력 <= 피쳐 갯수, iris 4개
#     * 은닉층 : 마음대로
#     * 출력층 : 출력 <= [분류] 타겟 클래스 갯수 [회귀] 1개

# %%
class IrisModel(nn.Module):
    def __init__(self, idim, odim):
        super().__init__()
        self.seq = nn.Sequential(
            nn.Linear(idim, 8),
            nn.ReLU(),
            nn.Linear(8, 4),
            nn.Linear(4, 2),
            nn.ReLU(),
            nn.Linear(2, odim)
        )
        
    def forward(self, x):
        return self.seq(x)

# %%
model = IrisModel(4, 3)

# %%
from torch import optim

optim = optim.Adam(model.parameters(), lr=0.01)

# %%
for i in trainDL:
    print(i[0]), print(i[1])
# Out:
# tensor([[4.4000, 3.2000, 1.3000, 0.2000],
#         [5.7000, 3.0000, 4.2000, 1.2000],
#         [4.8000, 3.1000, 1.6000, 0.2000],
#         [5.6000, 2.9000, 3.6000, 1.3000],
#         [6.9000, 3.1000, 4.9000, 1.5000]], dtype=torch.float64)
# tensor([[0],
#         [1],
#         [0],
#         [1],
#         [1]])
# tensor([[5.0000, 3.2000, 1.2000, 0.2000],
#         [7.4000, 2.8000, 6.1000, 1.9000],
#         [5.0000, 3.5000, 1.3000, 0.3000],
#         [5.8000, 2.7000, 3.9000, 1.2000],
#         [5.1000, 3.5000, 1.4000, 0.3000]], dtype=torch.float64)
# tensor([[0],
#         [2],
#         [0],
#         [1],
#         [0]])
# tensor([[6.7000, 2.5000, 5.8000, 1.8000],
#         [5.6000, 2.7000, 4.2000, 1.3000],
#         [6.2000, 2.2000, 4.5000, 1.5000],
#         [6.2000, 2.9000, 4.3000, 1.3000],
#         [7.7000, 3.8000, 6.7000, 2.2000]], dtype=torch.float64)
# tensor([[2],
#         [1],
#         [1],
#         [1],
#         [2]])
# tensor([[6.1000, 3.0000, 4.9000, 1.8000],
#         [4.5000, 2.3000, 1.3000, 0.3000],
#         [5.1000, 3.8000, 1.9000, 0.4000],
#         [4.9000, 2.4000, 3.3000, 1.0000],
#         [6.7000, 3.1000, 5.6000, 2.4000]], dtype=torch.float64)
# tensor([[2],
#         [0],
#         [0],
#         [1],
#         [2]])
# tensor([[5.9000, 3.0000, 5.1000, 1.8000],
#         [5.2000, 4.1000, 1.5000, 0.1000],
#         [5.1000, 3.3000, 1.7000, 0.5000],
#         [7.1000, 3.0000, 5.9000, 2.1000],
#         [5.4000, 3.9000, 1.3000, 0.4000]], dtype=torch.float64)
# tensor([[2],
#         [0],
#         [0],
#         [2],
#         [0]])
# tensor([[5.7000, 2.5000, 5.0000, 2.0000],
#         [6.1000, 2.8000, 4.0000, 1.3000],
#         [5.7000, 3.8000, 1.7000, 0.3000],
#         [5.8000, 2.7000, 4.1000, 1.0000],
#         [5.6000, 3.0000, 4.5000, 1.5000]], dtype=torch.float64)
# tensor([[2],
#         [1],
#         [0],
#         [1],
#         [1]])
# tensor([[5.1000, 3.5000, 1.4000, 0.2000],
#         [5.0000, 3.0000, 1.6000, 0.2000],
#         [5.8000, 2.7000, 5.1000, 1.9000],
#         [6.8000, 3.0000, 5.5000, 2.1000],
#         [6.1000, 3.0000, 4.6000, 1.4000]], dtype=torch.float64)
# tensor([[0],
#         [0],
#         [2],
#         [2],
#         [1]])
# tensor([[4.6000, 3.1000, 1.5000, 0.2000],
#         [5.2000, 2.7000, 3.9000, 1.4000],
#         [6.5000, 3.0000, 5.5000, 1.8000],
#         [6.7000, 3.1000, 4.7000, 1.5000],
#         [5.4000, 3.0000, 4.5000, 1.5000]], dtype=torch.float64)
# tensor([[0],
#         [1],
#         [2],
#         [1],
#         [1]])
# tensor([[4.9000, 2.5000, 4.5000, 1.7000],
#         [5.8000, 2.7000, 5.1000, 1.9000],
#         [5.0000, 3.5000, 1.6000, 0.6000],
#         [5.1000, 3.4000, 1.5000, 0.2000],
#         [5.0000, 3.4000, 1.6000, 0.4000]], dtype=torch.float64)
# tensor([[2],
#         [2],
#         [0],
#         [0],
#         [0]])
# tensor([[5.1000, 2.5000, 3.0000, 1.1000],
#         [5.0000, 2.3000, 3.3000, 1.0000],
#         [5.4000, 3.4000, 1.7000, 0.2000],
#         [6.3000, 2.3000, 4.4000, 1.3000],
#         [5.1000, 3.8000, 1.5000, 0.3000]], dtype=torch.float64)
# tensor([[1],
#         [1],
#         [0],
#         [1],
#         [0]])
# tensor([[6.9000, 3.2000, 5.7000, 2.3000],
#         [5.8000, 2.8000, 5.1000, 2.4000],
#         [5.0000, 3.4000, 1.5000, 0.2000],
#         [6.1000, 2.9000, 4.7000, 1.4000],
#         [6.8000, 2.8000, 4.8000, 1.4000]], dtype=torch.float64)
# tensor([[2],
#         [2],
#         [0],
#         [1],
#         [1]])
# tensor([[5.5000, 2.5000, 4.0000, 1.3000],
#         [5.5000, 3.5000, 1.3000, 0.2000],
#         [4.8000, 3.0000, 1.4000, 0.3000],
#         [4.9000, 3.1000, 1.5000, 0.1000],
#         [6.3000, 3.3000, 4.7000, 1.6000]], dtype=torch.float64)
# tensor([[1],
#         [0],
#         [0],
#         [0],
#         [1]])
# tensor([[6.6000, 2.9000, 4.6000, 1.3000],
#         [7.7000, 2.8000, 6.7000, 2.0000],
#         [6.4000, 3.2000, 4.5000, 1.5000],
#         [6.7000, 3.0000, 5.2000, 2.3000],
#         [4.8000, 3.4000, 1.9000, 0.2000]], dtype=torch.float64)
# tensor([[1],
#         [2],
#         [1],
#         [2],
#         [0]])
# tensor([[5.1000, 3.7000, 1.5000, 0.4000],
#         [7.6000, 3.0000, 6.6000, 2.1000],
#         [6.0000, 2.2000, 4.0000, 1.0000],
#         [5.7000, 4.4000, 1.5000, 0.4000],
#         [4.8000, 3.4000, 1.6000, 0.2000]], dtype=torch.float64)
# tensor([[0],
#         [2],
#         [1],
#         [0],
#         [0]])
# tensor([[5.3000, 3.7000, 1.5000, 0.2000],
#         [6.3000, 2.8000, 5.1000, 1.5000],
#         [5.6000, 3.0000, 4.1000, 1.3000],
#         [7.0000, 3.2000, 4.7000, 1.4000],
#         [4.6000, 3.4000, 1.4000, 0.3000]], dtype=torch.float64)
# tensor([[0],
#         [2],
#         [1],
#         [1],
#         [0]])
# tensor([[6.1000, 2.6000, 5.6000, 1.4000],
#         [6.4000, 2.7000, 5.3000, 1.9000],
#         [4.4000, 2.9000, 1.4000, 0.2000],
#         [5.0000, 3.3000, 1.4000, 0.2000],
#         [6.6000, 3.0000, 4.4000, 1.4000]], dtype=torch.float64)
# tensor([[2],
#         [2],
#         [0],
#         [0],
#         [1]])
# tensor([[5.6000, 2.5000, 3.9000, 1.1000],
#         [6.7000, 3.3000, 5.7000, 2.1000],
#         [5.0000, 3.6000, 1.4000, 0.2000],
#         [6.5000, 3.0000, 5.2000, 2.0000],
#         [5.5000, 2.4000, 3.8000, 1.1000]], dtype=torch.float64)
# tensor([[1],
#         [2],
#         [0],
#         [2],
#         [1]])
# tensor([[6.3000, 3.3000, 6.0000, 2.5000],
#         [5.7000, 2.8000, 4.1000, 1.3000],
#         [6.9000, 3.1000, 5.1000, 2.3000],
#         [4.6000, 3.2000, 1.4000, 0.2000],
#         [7.3000, 2.9000, 6.3000, 1.8000]], dtype=torch.float64)
# tensor([[2],
#         [1],
#         [2],
#         [0],
#         [2]])
# tensor([[4.3000, 3.0000, 1.1000, 0.1000],
#         [7.2000, 3.6000, 6.1000, 2.5000],
#         [7.2000, 3.0000, 5.8000, 1.6000],
#         [5.2000, 3.4000, 1.4000, 0.2000],
#         [4.4000, 3.0000, 1.3000, 0.2000]], dtype=torch.float64)
# tensor([[0],
#         [2],
#         [2],
#         [0],
#         [0]])
# tensor([[5.5000, 2.3000, 4.0000, 1.3000],
#         [5.6000, 2.8000, 4.9000, 2.0000],
#         [5.4000, 3.9000, 1.7000, 0.4000],
#         [5.7000, 2.8000, 4.5000, 1.3000],
#         [5.4000, 3.4000, 1.5000, 0.4000]], dtype=torch.float64)
# tensor([[1],
#         [2],
#         [0],
#         [1],
#         [0]])
# tensor([[6.1000, 2.8000, 4.7000, 1.2000],
#         [6.4000, 2.9000, 4.3000, 1.3000],
#         [6.5000, 2.8000, 4.6000, 1.5000],
#         [4.7000, 3.2000, 1.6000, 0.2000],
#         [4.8000, 3.0000, 1.4000, 0.1000]], dtype=torch.float64)
# tensor([[1],
#         [1],
#         [1],
#         [0],
#         [0]])

# %%
target.squeeze()
# Out:
# tensor([1, 1, 1, 0, 0])

# %%
for i in validDL:
    print(i[0]), print(i[1])
# Out:
# tensor([[4.6000, 3.6000, 1.0000, 0.2000],
#         [6.5000, 3.0000, 5.8000, 2.2000],
#         [5.5000, 2.4000, 3.7000, 1.0000],
#         [4.9000, 3.0000, 1.4000, 0.2000],
#         [6.3000, 2.9000, 5.6000, 1.8000]], dtype=torch.float64)
# tensor([[0],
#         [2],
#         [1],
#         [0],
#         [2]])
# tensor([[7.2000, 3.2000, 6.0000, 1.8000],
#         [6.0000, 3.4000, 4.5000, 1.6000],
#         [4.7000, 3.2000, 1.3000, 0.2000],
#         [5.7000, 2.9000, 4.2000, 1.3000],
#         [6.4000, 2.8000, 5.6000, 2.1000]], dtype=torch.float64)
# tensor([[2],
#         [1],
#         [0],
#         [1],
#         [2]])
# tensor([[5.2000, 3.5000, 1.5000, 0.2000],
#         [7.7000, 2.6000, 6.9000, 2.3000],
#         [6.7000, 3.0000, 5.0000, 1.7000],
#         [6.5000, 3.2000, 5.1000, 2.0000],
#         [6.3000, 2.5000, 5.0000, 1.9000]], dtype=torch.float64)
# tensor([[0],
#         [2],
#         [1],
#         [2],
#         [2]])

# %%
max_epoch = 1000
for e in range(1, max_epoch+1):
    for feature, target in trainDL:
        model.train()
        h = model(feature.float())
        
        cost = nn.functional.cross_entropy(h, target.squeeze())
        
        optim.zero_grad()
        cost.backward()
        optim.step()
    
    print(f'Epoch [{e:2} / {max_epoch}] ---')    
    model.eval()
    for i, (feature, target) in enumerate(validDL):
        v = model(feature.float())
        print(f'validset [{i}] cost : {cost.item():.6} accuracy : {(sum(v.argmax(dim=1) == target.squeeze(dim=1)) / len(v) * 100)}%')
# Out:
# Epoch [ 1 / 1000] ---
# validset [0] cost : 1.26282 accuracy : 40.0%
# validset [1] cost : 1.26282 accuracy : 40.0%
# validset [2] cost : 1.26282 accuracy : 60.000003814697266%
# Epoch [ 2 / 1000] ---
# validset [0] cost : 1.18205 accuracy : 40.0%
# validset [1] cost : 1.18205 accuracy : 40.0%
# validset [2] cost : 1.18205 accuracy : 60.000003814697266%
# Epoch [ 3 / 1000] ---
# validset [0] cost : 1.1287 accuracy : 40.0%
# validset [1] cost : 1.1287 accuracy : 40.0%
# validset [2] cost : 1.1287 accuracy : 60.000003814697266%
# Epoch [ 4 / 1000] ---
# validset [0] cost : 1.09456 accuracy : 20.0%
# validset [1] cost : 1.09456 accuracy : 40.0%
# validset [2] cost : 1.09456 accuracy : 20.0%
# Epoch [ 5 / 1000] ---
# validset [0] cost : 1.07271 accuracy : 40.0%
# validset [1] cost : 1.07271 accuracy : 20.0%
# validset [2] cost : 1.07271 accuracy : 20.0%
# Epoch [ 6 / 1000] ---
# validset [0] cost : 1.05853 accuracy : 40.0%
# validset [1] cost : 1.05853 accuracy : 20.0%
# validset [2] cost : 1.05853 accuracy : 20.0%
# Epoch [ 7 / 1000] ---
# validset [0] cost : 1.04917 accuracy : 40.0%
# validset [1] cost : 1.04917 accuracy : 20.0%
# validset [2] cost : 1.04917 accuracy : 20.0%
# Epoch [ 8 / 1000] ---
# validset [0] cost : 1.04291 accuracy : 40.0%
# validset [1] cost : 1.04291 accuracy : 20.0%
# validset [2] cost : 1.04291 accuracy : 20.0%
# Epoch [ 9 / 1000] ---
# validset [0] cost : 1.03868 accuracy : 40.0%
# validset [1] cost : 1.03868 accuracy : 20.0%
# validset [2] cost : 1.03868 accuracy : 20.0%
# Epoch [10 / 1000] ---
# validset [0] cost : 1.03581 accuracy : 40.0%
# validset [1] cost : 1.03581 accuracy : 20.0%
# validset [2] cost : 1.03581 accuracy : 20.0%
# Epoch [11 / 1000] ---
# validset [0] cost : 1.03386 accuracy : 40.0%
# validset [1] cost : 1.03386 accuracy : 20.0%
# validset [2] cost : 1.03386 accuracy : 20.0%
# Epoch [12 / 1000] ---
# validset [0] cost : 1.03253 accuracy : 40.0%
# validset [1] cost : 1.03253 accuracy : 20.0%
# validset [2] cost : 1.03253 accuracy : 20.0%
# Epoch [13 / 1000] ---
# validset [0] cost : 1.03164 accuracy : 40.0%
# validset [1] cost : 1.03164 accuracy : 20.0%
# validset [2] cost : 1.03164 accuracy : 20.0%
# Epoch [14 / 1000] ---
# validset [0] cost : 1.03103 accuracy : 40.0%
# validset [1] cost : 1.03103 accuracy : 20.0%
# validset [2] cost : 1.03103 accuracy : 20.0%
# Epoch [15 / 1000] ---
# validset [0] cost : 1.03062 accuracy : 40.0%
# validset [1] cost : 1.03062 accuracy : 20.0%
# validset [2] cost : 1.03062 accuracy : 20.0%
# Epoch [16 / 1000] ---
# validset [0] cost : 1.03035 accuracy : 40.0%
# validset [1] cost : 1.03035 accuracy : 20.0%
# validset [2] cost : 1.03035 accuracy : 20.0%
# Epoch [17 / 1000] ---
# validset [0] cost : 1.03017 accuracy : 40.0%
# validset [1] cost : 1.03017 accuracy : 20.0%
# validset [2] cost : 1.03017 accuracy : 20.0%
# Epoch [18 / 1000] ---
# validset [0] cost : 1.03004 accuracy : 40.0%
# validset [1] cost : 1.03004 accuracy : 20.0%
# validset [2] cost : 1.03004 accuracy : 20.0%
# Epoch [19 / 1000] ---
# validset [0] cost : 1.02996 accuracy : 40.0%
# validset [1] cost : 1.02996 accuracy : 20.0%
# validset [2] cost : 1.02996 accuracy : 20.0%
# Epoch [20 / 1000] ---
# validset [0] cost : 1.02991 accuracy : 40.0%
# validset [1] cost : 1.02991 accuracy : 20.0%
# validset [2] cost : 1.02991 accuracy : 20.0%
# Epoch [21 / 1000] ---
# validset [0] cost : 1.02987 accuracy : 40.0%
# validset [1] cost : 1.02987 accuracy : 20.0%
# validset [2] cost : 1.02987 accuracy : 20.0%
# Epoch [22 / 1000] ---
# validset [0] cost : 1.02985 accuracy : 40.0%
# validset [1] cost : 1.02985 accuracy : 20.0%
# validset [2] cost : 1.02985 accuracy : 20.0%
# Epoch [23 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [24 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [25 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [26 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [27 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [28 / 1000] ---
# validset [0] cost : 1.02981 accuracy : 40.0%
# validset [1] cost : 1.02981 accuracy : 20.0%
# validset [2] cost : 1.02981 accuracy : 20.0%
# Epoch [29 / 1000] ---
# validset [0] cost : 1.02981 accuracy : 40.0%
# validset [1] cost : 1.02981 accuracy : 20.0%
# validset [2] cost : 1.02981 accuracy : 20.0%
# Epoch [30 / 1000] ---
# validset [0] cost : 1.02981 accuracy : 40.0%
# validset [1] cost : 1.02981 accuracy : 20.0%
# validset [2] cost : 1.02981 accuracy : 20.0%
# Epoch [31 / 1000] ---
# validset [0] cost : 1.02981 accuracy : 40.0%
# validset [1] cost : 1.02981 accuracy : 20.0%
# validset [2] cost : 1.02981 accuracy : 20.0%
# Epoch [32 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [33 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [34 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [35 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [36 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [37 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [38 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [39 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [40 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [41 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [42 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [43 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [44 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [45 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [46 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [47 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [48 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [49 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [50 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [51 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [52 / 1000] ---
# validset [0] cost : 1.02982 accuracy : 40.0%
# validset [1] cost : 1.02982 accuracy : 20.0%
# validset [2] cost : 1.02982 accuracy : 20.0%
# Epoch [53 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [54 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [55 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [56 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [57 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [58 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [59 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [60 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [61 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [62 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [63 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [64 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [65 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [66 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [67 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [68 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [69 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [70 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [71 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [72 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [73 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [74 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [75 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [76 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [77 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [78 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [79 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [80 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [81 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [82 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [83 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [84 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [85 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [86 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [87 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [88 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [89 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [90 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [91 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [92 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [93 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [94 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [95 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [96 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [97 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [98 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [99 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [100 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [101 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [102 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [103 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [104 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [105 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [106 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [107 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [108 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [109 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [110 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [111 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [112 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [113 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [114 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [115 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [116 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [117 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [118 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [119 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [120 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [121 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [122 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [123 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [124 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [125 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [126 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [127 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [128 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [129 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [130 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [131 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [132 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [133 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [134 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [135 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [136 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [137 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [138 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [139 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [140 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [141 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [142 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [143 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [144 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [145 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [146 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [147 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [148 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [149 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [150 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [151 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [152 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [153 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [154 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [155 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [156 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [157 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [158 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [159 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [160 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [161 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [162 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [163 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [164 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [165 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [166 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [167 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [168 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [169 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [170 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [171 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [172 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [173 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [174 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [175 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [176 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [177 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [178 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [179 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [180 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [181 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [182 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [183 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [184 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [185 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [186 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [187 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [188 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [189 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [190 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [191 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [192 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [193 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [194 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [195 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [196 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [197 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [198 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [199 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [200 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [201 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [202 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [203 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [204 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [205 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [206 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [207 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [208 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [209 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [210 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [211 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [212 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [213 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [214 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [215 / 1000] ---
# validset [0] cost : 1.02983 accuracy : 40.0%
# validset [1] cost : 1.02983 accuracy : 20.0%
# validset [2] cost : 1.02983 accuracy : 20.0%
# Epoch [216 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [217 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [218 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [219 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [220 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [221 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [222 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [223 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [224 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [225 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [226 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [227 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [228 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [229 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [230 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [231 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [232 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [233 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [234 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [235 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [236 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [237 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [238 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [239 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [240 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [241 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [242 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [243 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [244 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [245 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [246 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [247 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [248 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [249 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [250 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [251 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [252 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [253 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [254 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [255 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [256 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [257 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [258 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [259 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [260 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [261 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [262 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [263 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [264 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [265 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [266 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [267 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [268 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [269 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [270 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [271 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [272 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [273 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [274 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [275 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [276 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [277 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [278 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [279 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [280 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [281 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [282 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [283 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [284 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [285 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [286 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [287 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [288 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [289 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [290 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [291 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [292 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [293 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [294 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [295 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [296 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [297 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [298 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [299 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [300 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [301 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [302 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [303 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [304 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [305 / 1000] ---
# ...
# Epoch [900 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [901 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [902 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [903 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [904 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [905 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [906 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [907 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [908 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [909 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [910 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [911 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [912 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [913 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [914 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [915 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [916 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [917 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [918 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [919 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [920 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [921 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [922 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [923 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [924 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [925 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [926 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [927 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [928 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [929 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [930 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [931 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [932 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [933 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [934 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [935 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [936 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [937 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [938 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [939 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [940 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [941 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [942 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [943 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [944 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [945 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [946 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [947 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [948 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [949 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [950 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [951 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [952 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [953 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [954 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [955 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [956 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [957 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [958 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [959 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [960 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [961 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [962 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [963 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [964 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [965 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [966 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [967 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [968 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [969 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [970 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [971 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [972 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [973 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [974 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [975 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [976 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [977 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [978 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [979 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [980 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [981 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [982 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [983 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [984 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [985 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [986 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [987 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [988 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [989 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [990 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [991 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [992 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [993 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [994 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [995 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [996 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [997 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [998 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [999 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%
# Epoch [1000 / 1000] ---
# validset [0] cost : 1.02984 accuracy : 40.0%
# validset [1] cost : 1.02984 accuracy : 20.0%
# validset [2] cost : 1.02984 accuracy : 20.0%

# %%
import torchmetrics.functional as metrics

# %%
model.eval()
for i, (feature, target) in enumerate(testDL):
    v = model(feature.float())
    print(f'testset [{i}] accuracy : {metrics.accuracy(v.argmax(dim=1), target.squeeze(dim=1), task="multiclass", num_classes=3)}\n'
          f'              precision: {metrics.precision(v.argmax(dim=1), target.squeeze(dim=1), task="multiclass", num_classes=3)}\n'
          f'              recall   : {metrics.recall(v.argmax(dim=1), target.squeeze(dim=1), task="multiclass", num_classes=3)}\n'
          f'              f1-score : {metrics.f1_score(v.argmax(dim=1), target.squeeze(dim=1), task="multiclass", num_classes=3)}')
# Out:
# testset [0] accuracy : 0.0
#               precision: 0.0
#               recall   : 0.0
#               f1-score : 0.0
# testset [1] accuracy : 0.4000000059604645
#               precision: 0.4000000059604645
#               recall   : 0.4000000059604645
#               f1-score : 0.4000000059604645
# testset [2] accuracy : 0.4000000059604645
#               precision: 0.4000000059604645
#               recall   : 0.4000000059604645
#               f1-score : 0.4000000059604645
# testset [3] accuracy : 0.0
#               precision: 0.0
#               recall   : 0.0
#               f1-score : 0.0
# testset [4] accuracy : 0.0
#               precision: 0.0
#               recall   : 0.0
#               f1-score : 0.0
# testset [5] accuracy : 0.4000000059604645
#               precision: 0.4000000059604645
#               recall   : 0.4000000059604645
#               f1-score : 0.4000000059604645
